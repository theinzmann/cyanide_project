# %%
import numpy as np
import psi4
from scipy.interpolate import InterpolatedUnivariateSpline
import matplotlib.pyplot as plt

# %%
z_mat = """-1 1
C
N 1 **R**"""

# %%
r_array = np.concatenate((np.linspace(0.9, 1.2, 20),np.linspace(1.25,1.75,10)))

# %%
AUG_cc_pVTZ = []
cc_pVTZ = []
molecule_len = []

for val in r_array:
    molecule_geom = psi4.geometry(z_mat.replace('**R**', str(val)))
    molecule_len.append(molecule_geom)


for mol in molecule_len:
    energy = psi4.energy("CCSD/aug-cc-pVTZ", molecule=mol)
    AUG_cc_pVTZ.append(energy)
    energy = psi4.energy("CCSD/cc-pVTZ", molecule=mol)
    cc_pVTZ.append(energy)
    
#print(AUG_cc_pVTZ, '\n')
#print(cc_pVTZ)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-53-3c5da3aa86bc> in <module>
#       9
#      10 for mol in molecule_len:
# ---> 11     energy = psi4.energy("CCSD/aug-cc-pVTZ", molecule=mol)
#      12     AUG_cc_pVTZ.append(energy)
#      13     energy = psi4.energy("CCSD/cc-pVTZ", molecule=mol)
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/driver.py in energy(name, **kwargs)
#     506     # Bounce to CBS if "method/basis" name
#     507     if "/" in lowername:
# --> 508         return driver_cbs._cbs_gufunc(energy, name, ptype='energy', **kwargs)
#     509
#     510     # Commit to procedures['energy'] call hereafter
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/driver_cbs.py in _cbs_gufunc(func, total_method_name, **kwargs)
#    1947         optstash = p4util.OptionsState(['BASIS'])
#    1948         core.set_global_option('BASIS', basis)
# -> 1949         ptype_value, wfn = func(method_name, return_wfn=True, molecule=molecule, **kwargs)
#    1950         core.clean()
#    1951
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/driver.py in energy(name, **kwargs)
#     554             shutil.copy(item, targetfile)
#     555
# --> 556     wfn = procedures['energy'][lowername](lowername, molecule=molecule, **kwargs)
#     557
#     558     for postcallback in hooks['energy']['post']:
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/procrouting/proc.py in select_ccsd(name, **kwargs)
#     746         return
#     747     else:
# --> 748         return func(name, **kwargs)
#     749
#     750
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/procrouting/proc.py in run_ccenergy(name, **kwargs)
#    2260     ref_wfn = kwargs.get('ref_wfn', None)
#    2261     if ref_wfn is None:
# -> 2262         ref_wfn = scf_helper(name, **kwargs)  # C1 certified
#    2263
#    2264     if core.get_global_option("CC_TYPE") == "DF":
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/procrouting/proc.py in scf_helper(name, post_scf, **kwargs)
#    1361         use_c1 = True
#    1362
# -> 1363     e_scf = scf_wfn.compute_energy()
#    1364     for obj in [core]:
#    1365         for pv in ["SCF TOTAL ENERGY", "CURRENT ENERGY", "CURRENT REFERENCE ENERGY"]:
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py in scf_compute_energy(self)
#      82         self.initialize_jk(self.memory_jk_)
#      83     else:
# ---> 84         self.initialize()
#      85
#      86     try:
#
# /anaconda3/lib/python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py in scf_initialize(self)
#     195             mints.set_rel_basisset(self.get_basisset('BASIS_RELATIVISTIC'))
#     196
# --> 197         mints.one_electron_integrals()
#     198         self.initialize_jk(self.memory_jk_, jk=jk)
#     199         if self.V_potential():
#
# RuntimeError:
# Fatal Error: PSIO Error
# Error occurred in file: /Users/github/builds/conda-builds/psi4-multiout_1557977521159/work/psi4/src/psi4/libpsio/error.cc on line: 128
# The most recent 5 function calls were:

# %%
plt.plot(r_array,AUG_cc_pVTZ,'gx', label='aug-cc-pVTZ energy')
plt.plot(r_array,cc_pVTZ,'mx',label='cc-pVTZ Energy')
plt.legend(); plt.xlabel('Distance (Angstroms)'); plt.ylabel('Hartrees')
plt.title('Initial Energy Data'); plt.savefig('initial_energies.png', dpi=300)
plt.show()

# %%
### convert to A.U.
r_array_au = r_array*1.89
aug_spline = InterpolatedUnivariateSpline(r_array_au, AUG_cc_pVTZ, k=3)
cc_spline = InterpolatedUnivariateSpline(r_array_au, cc_pVTZ, k=3)

# %%
r_plot = np.linspace(0.9*1.89, 1.75*1.89, 250)
### computes the spline functions for two basis sets
inter_aug = aug_spline(r_plot)
inter_cc = cc_spline(r_plot)

### plots the spline functions and the original data for comparision
plt.figure()
plt.plot(r_plot, inter_aug, 'r-', label='AUG Spline')
plt.plot(r_array_au, AUG_cc_pVTZ, 'b+', label='AUG Data')
plt.plot(r_plot, inter_cc, 'g-', label='cc Spline')
plt.plot(r_array_au, cc_pVTZ, 'm+', label='cc Data')
plt.xlabel('Length in A.U.'); plt.ylabel('Hartrees'); plt.legend()
plt.title('PES of $CN^{-}$'); plt.savefig('pes_comparison.png', dpi=300)
plt.show()

# %%
### compute the function for the force plot
aug_force_spline = aug_spline.derivative()
cc_force_spline = cc_spline.derivative()

### plot the force spline functions
plt.figure()
plt.plot(r_plot, -1*aug_force_spline(r_plot), 'r-', label='aug-cc-pVTZ')
plt.plot(r_plot, -1*cc_force_spline(r_plot), 'b--', label='cc-pVTZ')
plt.xlabel('Distance (a.u.)'); plt.ylabel('Force')
plt.title('Plot of Forces for $CN^{-}$'); plt.legend()
plt.savefig('forces_plot.png', dpi=300)
plt.show()

# %%
### compute equilibrium bond length for both methods
aug_Req = r_plot[np.argmin(aug_spline(r_plot))]
cc_Req = r_plot[np.argmin(cc_spline(r_plot))]

print('The equilibrium bond length for the aug-cc-pVTz basis set is: {:.4f} Angstroms.'.format(aug_Req/1.89))
print('The equilibrium bond length for the cc-pVTZ basis set is:     {:.4f} Angstroms.'.format(cc_Req/1.89))
# Out:
# The equilibrium bond length for the aug-cc-pVTz basis set is: 1.1867 Angstroms.
# The equilibrium bond length for the cc-pVTZ basis set is:     1.1833 Angstroms.

# %%
### compute the force splines for each basis set
aug_constant_spline = aug_force_spline.derivative()
cc_constant_spline = cc_force_spline.derivative()

aug_force_constant = aug_constant_spline(aug_Req)
cc_force_constant = cc_constant_spline(cc_Req)

print('{}\n{}'.format(aug_force_constant, cc_force_constant))
# Out:
# 0.9792007767387039
# 1.0144095582068904

# %%
### compute reduced mass
scalar = 1.6605E-27/9.109E-31
mC = 12.0107*scalar; mN = 14.0067*scalar
mEff = (mC*mN)/(mC+mN)

# %%
### Compute the vibrational frequencies in a.u.
aug_cc_nu = 1/(2*np.pi)*np.sqrt(aug_force_constant/mEff)
cc_nu = 1/(2*np.pi)*np.sqrt(cc_force_constant/mEff)

aug_cc_nu_ev = 2*np.pi*aug_cc_nu *27.211
cc_nu_ev = 2*np.pi*cc_nu * 27.211


aug_freq = aug_cc_nu_ev * 241.8
cc_freq = cc_nu_ev * 241.8

print('{} THz\n{} THz'.format(aug_freq, cc_freq))
# Out:
# 0.2480139800874149
#
#  0.25243347949919215
# 59.96978038513693 THz
# 61.03841534290466 THz

# %%
print(F'{2169.46 * 2.998E10:.5e} Hz')
print(F'{cc_freq*1E12:.5e} Hz')
# Out:
# 6.50404e+13 Hz
# 6.10384e+13 Hz
